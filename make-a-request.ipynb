# %% [markdown]
# # Install dependencies

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (0.96.0)
# Requirement already satisfied: python-dotenv in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (2.13.2)
# Requirement already satisfied: sniffio in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nakulnagariya\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Load environment variables

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # Create a API client

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"
max_tokens = 1000

# %% [markdown]
# # make a request to the API

# %%
def add_user_message(messages, content):
    user_message = {
            "role": "user",
            "content": content,
        }
    messages.append(user_message)


def add_assistant_message(messages, content):
    assistant_message = {
            "role": "assistant",
            "content": content,
        }
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=max_tokens,
        messages=messages
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "What is the capital of France?")

answer = chat(messages)

add_assistant_message(messages, answer)

add_user_message(messages, "tell me more about this city?")

answer = chat(messages)

answer
# Out:
# '# Paris\n\nParis is one of the world\'s most iconic and visited cities. Here are some key aspects:\n\n## Geography & Size\n- Located in north-central France along the Seine River\n- Population of about 2.2 million in the city proper, over 12 million in the metropolitan area\n- Divided into 20 districts called "arrondissements" that spiral outward from the center\n\n## Famous Landmarks\n- **Eiffel Tower** - iconic iron lattice tower built in 1889\n- **Louvre Museum** - world\'s largest art museum, home to the Mona Lisa\n- **Notre-Dame Cathedral** - medieval Gothic masterpiece (currently under restoration after 2019 fire)\n- **Arc de Triomphe** - monument honoring French soldiers\n- **Sacré-Cœur** - white basilica on Montmartre hill\n- **Champs-Élysées** - famous avenue for shopping and cafés\n\n## Culture\n- Known as the "City of Light" (La Ville Lumière)\n- Major center for art, fashion, gastronomy, and culture\n- Home to numerous museums, theaters, and galleries\n- Famous for café culture, bistros, and fine dining\n- Fashion capital with Paris Fashion Week\n\n## History\n- Over 2,000 years old, founded by the Parisii Celtic tribe\n- Capital of France since the 12th century\n- Site of major historical events including the French Revolution\n\nIs there any particular aspect of Paris you\'d like to know more about?'
